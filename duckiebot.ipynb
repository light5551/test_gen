# %% [markdown]
# <a href="https://colab.research.google.com/github/light5551/test_gen/blob/master/duckiebot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import cv2
img = cv2.imread('/content/sample_data/duckiebot.png', 0)
print(type(img))

plt.imshow(img)
plt.show()
# Out:
# <class 'numpy.ndarray'>
